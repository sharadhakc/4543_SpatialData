# %% [markdown]
# # 🧙 Magic Commands Demo Notebook
#
# This notebook introduces some of the most useful **IPython magic commands** in Jupyter.
# Run each cell and see what happens!

# %% [markdown]
# ## 1. Timing and Performance

# %%
# %time sum(range(1_000_000))
# Out:
# CPU times: total: 46.9 ms
# Wall time: 38.6 ms
# 499999500000

# %%
# %timeit sum(range(1_000_000))
# Out:
# 32.2 ms ± 1.73 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%time
total = 0
for i in range(1_000_000):
    total += i
# Out:
# CPU times: total: 219 ms
# Wall time: 217 ms

# %% [markdown]
# ## 2. Working with Files

# %%
# %pwd
# Out:
# 'c:\\Users\\shara\\Downloads\\data spati\\4543_SpatialData\\Assignments\\01-Python_Foundations\\04-Foundations\\Lessons\\01-Magic_Commands'

# %%
# %ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 840C-CBE0
#
#  Directory of c:\Users\shara\Downloads\data spati\4543_SpatialData\Assignments\01-Python_Foundations\04-Foundations\Lessons\01-Magic_Commands
#
# 04/25/2026  12:10 AM    <DIR>          .
# 04/25/2026  12:10 AM    <DIR>          ..
# 04/25/2026  12:10 AM                25 _autogen.md
# 04/25/2026  12:10 AM                23 _header.md
# 04/25/2026  12:10 AM            10,532 01-magic_commands.ipynb
# 04/25/2026  12:10 AM                40 meta.yaml
# 04/25/2026  12:10 AM                18 README.md
#                5 File(s)         10,638 bytes
#                2 Dir(s)  179,762,081,792 bytes free

# %%
# %cd ..
# %pwd
# Out:
# c:\Users\shara\Downloads\data spati\4543_SpatialData\Assignments\01-Python_Foundations\04-Foundations\Lessons
# 'c:\\Users\\shara\\Downloads\\data spati\\4543_SpatialData\\Assignments\\01-Python_Foundations\\04-Foundations\\Lessons'

# %% [markdown]
# ## 3. Variables in Memory

# %%
a = 42
b = [1, 2, 3]
c = {"name": "Graylian"}

# %who
# Out:
# a	 b	 c

# %%
# %whos
# Out:
# Variable   Type    Data/Info
# ----------------------------
# a          int     42
# b          list    n=3
# c          dict    n=1

# %%
# %reset

# %% [markdown]
# ## 4. Debugging and Introspection

# %%
1 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 1 / 0
#
# ZeroDivisionError: division by zero

# %%
# %debug
# Out:
# ERROR:root:No traceback has been produced, nothing to debug.

# %% [markdown]
# ## 5. Writing and Running Files

# %%
# %%writefile hello.py
print("Hello from a file!")
# Out:
# Writing hello.py

# %%
# %run hello.py
# Out:
# Hello from a file!

# %% [markdown]
# ## 6. Output and Formatting

# %%
# %%capture cap
print("This will not display right away")

cap.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 print("This will not display right away")
#       2
# ----> 3 cap.show()
#
# NameError: name 'cap' is not defined

# %%
# %%html
# <h1 style="color: maroon">Magics are Magical ✨</h1>
# Out:
# <h1 style="color: maroon">Magics are Magical ✨</h1>

# %%
# %%markdown
# # This is a Markdown cell inside code!
# **Bold text** and *italic* still work.

# %% [markdown]
# ## 7. Discover More

# %%
# %lsmagic

# %%
# %timeit?

# %% [markdown]
# ✅ **Try It Yourself**:
# - Use `%timeit` to compare a list comprehension `[x**2 for x in range(1000)]` vs a generator `(x**2 for x in range(1000))`.
# - Use `%whos` after defining some variables to see their types.
# - Use `%%html` to make your own banner.

# %%
a=9
# %whos
# Out:
# Variable   Type          Data/Info
# ----------------------------------
# a          int           9
# b          list          n=3
# c          dict          n=1
# cap        CapturedIO    This will not display right away\n

# %%
# %%html
# <h1 style= "color:pink"> Sharadha </h1>
# Out:
# <h1 style= "color:pink"> Sharadha </h1>

# %%
# %timeit [x**2 for x in range(1000)]
# %timeit (x**2 for x in range(1000))
# Out:
# 130 μs ± 4.18 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# 563 ns ± 7.19 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)
