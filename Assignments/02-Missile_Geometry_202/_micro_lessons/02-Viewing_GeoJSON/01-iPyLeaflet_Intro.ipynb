# %% [markdown]
# ## 01 — ipyleaflet Intro
#
# In the last lesson we used geojson.io to view and edit GeoJSON in the browser. This lesson brings the map **into the notebook**.
#
# **ipyleaflet** is a Python library that wraps the Leaflet.js mapping library. It renders interactive maps directly inside Jupyter — you can pan, zoom, click features, and update the map programmatically from Python.
#
# **ipywidgets** is the underlying widget framework that makes this possible. ipyleaflet's `Map`, markers, and layers are all widgets — objects that have live state and can respond to events. You do not need to understand all of ipywidgets to use ipyleaflet, but knowing it is there explains why the map is interactive rather than just a static image.

# %% [markdown]
# ## The Widget Model
#
# A regular matplotlib plot is static — once rendered, it is just an image. An ipyleaflet map is a **widget**: a live Python object linked to something rendered in the browser.
#
# ```
# Python object          Browser display
# ──────────────         ───────────────
# Map(zoom=10)    ←───►  interactive map tile
# Marker(...)     ←───►  draggable pin
# layer.add(...)  ←───►  updates the map in place
# ```
#
# This means you can add layers, move markers, or change zoom programmatically **after** the map is already displayed — without re-running the cell.

# %% [markdown]
# ## Your First Map
#
# All ipyleaflet maps start with `Map`. The two required parameters are `center` and `zoom`.
#
# `center` takes `[latitude, longitude]` — **note: this is lat/lon order**, the opposite of GeoJSON's `[lon, lat]`. This is a common source of confusion.

# %%
# !pip install ipyleaflet
# Out:
# Collecting ipyleaflet
#   Downloading ipyleaflet-0.20.0-py3-none-any.whl.metadata (5.3 kB)
# Collecting branca>=0.5.0 (from ipyleaflet)
#   Downloading branca-0.8.2-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in c:\users\shara\downloads\cnc\lib\site-packages (from ipyleaflet) (8.1.5)
# Collecting jupyter-leaflet<0.21,>=0.20 (from ipyleaflet)
#   Downloading jupyter_leaflet-0.20.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting traittypes<3,>=0.2.1 (from ipyleaflet)
#   Downloading traittypes-0.2.3-py2.py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: xyzservices>=2021.8.1 in c:\users\shara\downloads\cnc\lib\site-packages (from ipyleaflet) (2022.9.0)
# Requirement already satisfied: comm>=0.1.3 in c:\users\shara\appdata\roaming\python\python313\site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\shara\appdata\roaming\python\python313\site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet) (9.13.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\shara\appdata\roaming\python\python313\site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\users\shara\downloads\cnc\lib\site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet) (4.0.13)
# Requirement already satisfied: jupyterlab_widgets~=3.0.12 in c:\users\shara\downloads\cnc\lib\site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet) (3.0.13)
# Requirement already satisfied: jinja2>=3 in c:\users\shara\downloads\cnc\lib\site-packages (from branca>=0.5.0->ipyleaflet) (3.1.6)
# Requirement already satisfied: colorama>=0.4.4 in c:\users\shara\downloads\cnc\lib\site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.4.6)
# Requirement already satisfied: decorator>=5.1.0 in c:\users\shara\downloads\cnc\lib\site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (5.1.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\shara\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in c:\users\shara\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.6 in c:\users\shara\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\shara\downloads\cnc\lib\site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (3.0.43)
# Requirement already satisfied: psutil>=7 in c:\users\shara\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (7.2.2)
# Requirement already satisfied: pygments>=2.14.0 in c:\users\shara\downloads\cnc\lib\site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (2.19.1)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\shara\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.6.3)
# Requirement already satisfied: wcwidth in c:\users\shara\downloads\cnc\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\shara\appdata\roaming\python\python313\site-packages (from jedi>=0.18.2->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.8.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\shara\downloads\cnc\lib\site-packages (from jinja2>=3->branca>=0.5.0->ipyleaflet) (3.0.2)
# Requirement already satisfied: executing>=1.2.0 in c:\users\shara\appdata\roaming\python\python313\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\shara\appdata\roaming\python\python313\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (3.0.1)
# Requirement already satisfied: pure-eval in c:\users\shara\appdata\roaming\python\python313\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.2.3)
# Downloading ipyleaflet-0.20.0-py3-none-any.whl (31 kB)
# Downloading jupyter_leaflet-0.20.0-py3-none-any.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    ------------------ --------------------- 0.5/1.1 MB 404.5 kB/s eta 0:00:02
#    ------------------ --------------------- 0.5/1.1 MB 404.5 kB/s eta 0:00:02
#    ------------------ --------------------- 0.5/1.1 MB 404.5 kB/s eta 0:00:02
#    ------------------ --------------------- 0.5/1.1 MB 404.5 kB/s eta 0:00:02
#    ------------------ --------------------- 0.5/1.1 MB 404.5 kB/s eta 0:00:02
#    ------------------ --------------------- 0.5/1.1 MB 404.5 kB/s eta 0:00:02
#    ------------------ --------------------- 0.5/1.1 MB 404.5 kB/s eta 0:00:02
#    ---------------------------- ----------- 0.8/1.1 MB 261.6 kB/s eta 0:00:02
#    ---------------------------- ----------- 0.8/1.1 MB 261.6 kB/s eta 0:00:02
#    ---------------------------------------- 1.1/1.1 MB 323.6 kB/s eta 0:00:00
# Downloading traittypes-0.2.3-py2.py3-none-any.whl (8.1 kB)
# Downloading branca-0.8.2-py3-none-any.whl (26 kB)
# Installing collected packages: traittypes, jupyter-leaflet, branca, ipyleaflet
#
#    ---------------------------------------- 0/4 [traittypes]
#    -------------------- ------------------- 2/4 [branca]
#    ------------------------------ --------- 3/4 [ipyleaflet]
#    ------------------------------ --------- 3/4 [ipyleaflet]
#    ---------------------------------------- 4/4 [ipyleaflet]
#
# Successfully installed branca-0.8.2 ipyleaflet-0.20.0 jupyter-leaflet-0.20.0 traittypes-0.2.3

# %%
# !pip install ipywidgets
# Out:
# Requirement already satisfied: ipywidgets in c:\users\shara\downloads\cnc\lib\site-packages (8.1.5)
# Requirement already satisfied: comm>=0.1.3 in c:\users\shara\appdata\roaming\python\python313\site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\shara\appdata\roaming\python\python313\site-packages (from ipywidgets) (9.13.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\shara\appdata\roaming\python\python313\site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\users\shara\downloads\cnc\lib\site-packages (from ipywidgets) (4.0.13)
# Requirement already satisfied: jupyterlab_widgets~=3.0.12 in c:\users\shara\downloads\cnc\lib\site-packages (from ipywidgets) (3.0.13)
# Requirement already satisfied: colorama>=0.4.4 in c:\users\shara\downloads\cnc\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: decorator>=5.1.0 in c:\users\shara\downloads\cnc\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\shara\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in c:\users\shara\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.6 in c:\users\shara\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\shara\downloads\cnc\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.43)
# Requirement already satisfied: psutil>=7 in c:\users\shara\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets) (7.2.2)
# Requirement already satisfied: pygments>=2.14.0 in c:\users\shara\downloads\cnc\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.19.1)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\shara\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: wcwidth in c:\users\shara\downloads\cnc\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\shara\appdata\roaming\python\python313\site-packages (from jedi>=0.18.2->ipython>=6.1.0->ipywidgets) (0.8.6)
# Requirement already satisfied: executing>=1.2.0 in c:\users\shara\appdata\roaming\python\python313\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\shara\appdata\roaming\python\python313\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (3.0.1)
# Requirement already satisfied: pure-eval in c:\users\shara\appdata\roaming\python\python313\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (0.2.3)

# %%
from ipyleaflet import Map

# Wichita Falls, TX
WICHITA_FALLS = (33.9137, -98.4934)  # (lat, lon) — ipyleaflet order

m = Map(center=WICHITA_FALLS, zoom=12)
m
# Out:
# Map(center=[33.9137, -98.4934], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'z…

# %% [markdown]
# ## Zoom Levels
#
# Zoom is an integer roughly on this scale:
#
# | Zoom | What you see |
# |---|---|
# | 1–3 | whole continents |
# | 5–7 | country / state level |
# | 10–12 | city level |
# | 14–16 | neighborhood / street level |
# | 18+ | individual buildings |
#
# You can also zoom interactively with the scroll wheel or the `+`/`-` controls on the map.

# %% [markdown]
# ## Adding a Default Marker
#
# A `Marker` is the simplest feature — a pin at a location. Like the map itself, a marker is a widget: you add it to the map with `m.add(marker)`.

# %%
from ipyleaflet import Map, Marker

m = Map(center=WICHITA_FALLS, zoom=13)

# Marker location is also (lat, lon)
city_hall = Marker(location=(33.9137, -98.4934), title="Wichita Falls City Hall")
m.add(city_hall)

m
# Out:
# Map(center=[33.9137, -98.4934], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'z…

# %% [markdown]
# ## Multiple Markers
#
# You can add as many markers as you want. Build them in a loop and call `m.add()` for each one.

# %%
from ipyleaflet import Map, Marker

m = Map(center=WICHITA_FALLS, zoom=12)

locations = [
    {"name": "Wichita Falls City Hall",   "lat": 33.9137, "lon": -98.4934},
    {"name": "Midwestern State University","lat": 33.8956, "lon": -98.5187},
    {"name": "Lake Wichita",               "lat": 33.8627, "lon": -98.5457},
    {"name": "Lucy Park",                  "lat": 33.9281, "lon": -98.5071},
]

for loc in locations:
    marker = Marker(location=(loc["lat"], loc["lon"]), title=loc["name"])
    m.add(marker)

m
# Out:
# Map(center=[33.9137, -98.4934], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'z…

# %% [markdown]
# ## Custom Markers with AwesomeIcon
#
# The default marker is a blue teardrop. `AwesomeIcon` lets you swap in any [Font Awesome](https://fontawesome.com/v4/icons/) icon and change the color.
#
# Available `marker_color` values: `"red"`, `"blue"`, `"green"`, `"purple"`, `"orange"`, `"darkred"`, `"lightred"`, `"beige"`, `"darkblue"`, `"darkgreen"`, `"cadetblue"`, `"darkpurple"`, `"white"`, `"pink"`, `"lightblue"`, `"lightgreen"`, `"gray"`, `"lightgray"`, `"black"`

# %%
from ipyleaflet import Map, Marker, AwesomeIcon

m = Map(center=WICHITA_FALLS, zoom=12)

# university — book icon, dark blue
university_icon = AwesomeIcon(name="graduation-cap", marker_color="darkblue", icon_color="white")
university = Marker(
    location=(33.8956, -98.5187),
    icon=university_icon,
    title="Midwestern State University"
)

# park — tree icon, green
park_icon = AwesomeIcon(name="tree", marker_color="green", icon_color="white")
park = Marker(
    location=(33.9281, -98.5071),
    icon=park_icon,
    title="Lucy Park"
)

# lake — tint (water drop) icon, cadetblue
lake_icon = AwesomeIcon(name="tint", marker_color="cadetblue", icon_color="white")
lake = Marker(
    location=(33.8627, -98.5457),
    icon=lake_icon,
    title="Lake Wichita"
)

m.add(university)
m.add(park)
m.add(lake)

m
# Out:
# Map(center=[33.9137, -98.4934], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'z…

# %% [markdown]
# ## Popup Messages
#
# A `Popup` attaches an HTML label to a marker that appears when you click it. Use `ipywidgets.HTML` to define the content.

# %%
from ipyleaflet import Map, Marker, Popup
from ipywidgets import HTML

m = Map(center=WICHITA_FALLS, zoom=13)

marker = Marker(location=(33.9137, -98.4934))

popup_content = HTML(value="""
    <b>Wichita Falls, TX</b><br>
    Population: ~100,000<br>
    Founded: 1876
""")

marker.popup = popup_content
m.add(marker)

m
# Out:
# Map(center=[33.9137, -98.4934], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'z…

# %% [markdown]
# ## Changing the Tile Layer
#
# The default background tiles are OpenStreetMap. ipyleaflet ships with several alternatives via `basemaps`.

# %%
from ipyleaflet import Map, basemaps

# satellite imagery
m = Map(
    center=WICHITA_FALLS,
    zoom=12,
    basemap=basemaps.Esri.WorldImagery
)
m
# Out:
# Map(center=[33.9137, -98.4934], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'z…

# %% [markdown]
# Other useful basemaps:
#
# ```python
# basemaps.OpenStreetMap.Mapnik      # default street map
# basemaps.Esri.WorldImagery         # satellite
# basemaps.Esri.NatGeoWorldMap       # National Geographic style
# basemaps.CartoDB.Positron          # light/minimal
# basemaps.CartoDB.DarkMatter        # dark mode
# basemaps.OpenTopoMap               # topographic
# ```

# %% [markdown]
# ## Exercise A
#
# Pick 3 US cities you know. Look up their `(lat, lon)` coordinates and add a default `Marker` for each — with `title` set to the city name — on a zoom-5 map centered roughly over the US.

# %%
from ipyleaflet import Map, Marker

# Pick 3 US cities you know. Look up their (lat, lon) coordinates.
# Add a default Marker for each with a title set to the city name.
# Center the map at zoom 5 so all three are visible.
# Your code here

m = Map(center=(39.5, -98.35), zoom=5)

cities = [
    {"name": "Denver",       "lat": 39.7392, "lon": -104.9903},
    {"name": "Seattle",      "lat": 47.6062, "lon": -122.3321},
    {"name": "New York City","lat": 40.7128, "lon": -74.0060},
]

for city in cities:
    marker = Marker(location=(city["lat"], city["lon"]), title=city["name"])
    m.add(marker)

m
# Out:
# Map(center=[39.5, -98.35], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_o…

# %% [markdown]
# ## Exercise B
#
# Take one of your markers from Exercise A and attach a `Popup` using `ipywidgets.HTML`. The popup should display the city name and one fact (population, founding year, or elevation) when clicked.

# %%
from ipyleaflet import Map, Marker
from ipywidgets import HTML

# Build on Exercise A — attach a popup to one of your markers
# The popup should show the city name and one fact (population, elevation, or founding year)
# Your code here

m = Map(center=(39.5, -98.35), zoom=5)
denver = Marker(location=(39.7392, -104.9903), title="Denver")
denver.popup = HTML(value="""
    <b>Denver, CO</b><br>
    Population: ~715,000<br>
    Elevation: 5,280 ft (the Mile High City)
""")
m.add(denver)
# Out:
# Map(center=[39.5, -98.35], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_o…

# %% [markdown]
# ---
#
# ## Check Your Understanding
#
# Using the locations below, build a map centered on Wichita Falls at zoom 11 with **three custom markers** — each with a different `AwesomeIcon` color and a popup that shows the location name.
#
# ```python
# spots = [
#     {"name": "Wichita Falls Regional Airport", "lat": 33.9898, "lon": -98.4919},
#     {"name": "Sikes Senter Mall",               "lat": 33.8994, "lon": -98.5380},
#     {"name": "MPEC Arena",                      "lat": 33.9113, "lon": -98.4958},
# ]
# ```
#
# ```python
# # your answer here
# ```

# %%
from ipyleaflet import Map, Marker, AwesomeIcon
from ipywidgets import HTML

m = Map(center=(33.9137, -98.4934), zoom=11)

spots = [
    {"name": "Wichita Falls Regional Airport", "lat": 33.9898, "lon": -98.4919, "icon": "plane",         "color": "purple"},
    {"name": "Sikes Senter Mall",               "lat": 33.8994, "lon": -98.5380, "icon": "shopping-cart", "color": "lightred"},
    {"name": "MPEC Arena",                      "lat": 33.9113, "lon": -98.4958, "icon": "ticket",        "color": "orange"},
]

for spot in spots:
    icon = AwesomeIcon(name=spot["icon"], marker_color=spot["color"], icon_color="white")
    marker = Marker(location=(spot["lat"], spot["lon"]), icon=icon, title=spot["name"])
    marker.popup = HTML(value=f"<b>{spot['name']}</b>")
    m.add(marker)

m
# Out:
# Map(center=[33.9137, -98.4934], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'z…

# %% [markdown]
# ## Next
#
# In [02 — Adding a GeoJSON Layer](./02-Add_GeoJSON.ipynb), we move from individual markers to rendering whole FeatureCollections in a single call.
